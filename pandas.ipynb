# %%
import numpy as np
import pandas as pd

# %%
dict1= {
    "name":['raushan','rahul','gautam','prince'],
    "marks":[90,34,67,45],
    "city":['sheohar','tariyani','kolkata','belahiyan']
}

# %%
rau = pd.DataFrame(dict1)

# %%
rau
# Out:
#       name  marks       city
# 0  raushan     90    sheohar
# 1    rahul     34   tariyani
# 2   gautam     67    kolkata
# 3   prince     45  belahiyan

# %%
rau.to_csv('raushan.csv',index = False)

# %%
rau.head(2)
# Out:
#       name  marks      city
# 0  raushan     90   sheohar
# 1    rahul     34  tariyani

# %%
rau.tail(3)
# Out:
#      name  marks       city
# 1   rahul     34   tariyani
# 2  gautam     67    kolkata
# 3  prince     45  belahiyan

# %%
rau.describe()
# Out:
#            marks
# count   4.000000
# mean   59.000000
# std    24.805913
# min    34.000000
# 25%    42.250000
# 50%    56.000000
# 75%    72.750000
# max    90.000000

# %%
raushan = pd.read_csv('raushan.csv')

# %%
raushan
# Out:
#       name  marks       city
# 0  raushan     90    sheohar
# 1    rahul     34   tariyani
# 2   gautam     67    kolkata
# 3   prince     45  belahiyan

# %%
raushan['name']
# Out:
# 0    raushan
# 1      rahul
# 2     gautam
# 3     prince
# Name: name, dtype: object

# %%
raushan['marks']
# Out:
# 0    90
# 1    34
# 2    67
# 3    45
# Name: marks, dtype: int64

# %%
raushan[['name','city']]
# Out:
#       name       city
# 0  raushan    sheohar
# 1    rahul   tariyani
# 2   gautam    kolkata
# 3   prince  belahiyan

# %%
raushan[['name','city','marks']]
# Out:
#       name       city  marks
# 0  raushan    sheohar     90
# 1    rahul   tariyani     34
# 2   gautam    kolkata     67
# 3   prince  belahiyan     45

# %%
raushan['marks'][0]
# Out:
# np.int64(90)

# %%
raushan['name'][0]
# Out:
# 'raushan'

# %%
raushan['marks'][0] = 100
# Out:
# C:\Users\RAUSHAN KUMAR\AppData\Local\Temp\ipykernel_8556\1266255689.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raushan['marks'][0] = 100

# %%
raushan
# Out:
#       name  marks       city
# 0  raushan    100    sheohar
# 1    rahul     34   tariyani
# 2   gautam     67    kolkata
# 3   prince     45  belahiyan

# %%
raushan.to_csv('raushan.csv',index = False)

# %%
raushan.index = ['first','second','thied','fourth']

# %%
raushan
# Out:
#            name  marks       city
# first   raushan    100    sheohar
# second    rahul     34   tariyani
# thied    gautam     67    kolkata
# fourth   prince     45  belahiyan

# %%
ser = pd.Series(np.random.rand(34))

# %%
ser
# Out:
# 0     0.180025
# 1     0.996762
# 2     0.779670
# 3     0.323843
# 4     0.171859
# 5     0.984004
# 6     0.450181
# 7     0.457743
# 8     0.495261
# 9     0.893492
# 10    0.977760
# 11    0.067977
# 12    0.286821
# 13    0.230977
# 14    0.438225
# 15    0.709399
# 16    0.850537
# 17    0.834908
# 18    0.892067
# 19    0.368409
# 20    0.759264
# 21    0.596927
# 22    0.125261
# 23    0.244676
# 24    0.690708
# 25    0.356048
# 26    0.287567
# 27    0.216969
# 28    0.331019
# 29    0.221261
# 30    0.084616
# 31    0.662678
# 32    0.774085
# 33    0.476690
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf = pd.DataFrame(np.random.rand(334,5), index = np.arange(334))

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0
ascending = False)
# Out:
#             4         3         2         1         0
# 0    0.432445  0.732249  0.696546  0.402848   raushan
# 1    0.400661  0.278287  0.504721  0.513092  0.861833
# 2    0.341054  0.367286  0.814329  0.862285  0.858289
# 3    0.976024  0.340316  0.089836  0.393929  0.906266
# 4    0.431530  0.400450  0.456067  0.600327   0.85777
# ..        ...       ...       ...       ...       ...
# 329  0.961394  0.892920  0.594165  0.617081   0.47562
# 330  0.880603  0.755304  0.724146  0.904089  0.531252
# 331  0.176400  0.183396  0.575742  0.557048  0.958849
# 332  0.002875  0.734708  0.797065  0.741138  0.391368
# 333  0.516512  0.904151  0.201650  0.004630  0.406627
#
# [334 rows x 5 columns]

# %%
newdf[0]
# Out:
# 0       raushan
# 1      0.861833
# 2      0.858289
# 3      0.906266
# 4       0.85777
#          ...
# 329     0.47562
# 330    0.531252
# 331    0.958849
# 332    0.391368
# 333    0.406627
# Name: 0, Length: 334, dtype: object

# %%
type(newdf[0])
# Out:
# pandas.core.series.Series

# %%
newdf2 = newdf

# %%
newdf2[0][0] = 9793

# %%
newdf
# Out:
#             0         1         2         3         4
# 0        9793  0.402848  0.696546  0.732249  0.432445
# 1    0.861833  0.513092  0.504721  0.278287  0.400661
# 2    0.858289  0.862285  0.814329  0.367286  0.341054
# 3    0.906266  0.393929  0.089836  0.340316  0.976024
# 4     0.85777  0.600327  0.456067  0.400450  0.431530
# ..        ...       ...       ...       ...       ...
# 329   0.47562  0.617081  0.594165  0.892920  0.961394
# 330  0.531252  0.904089  0.724146  0.755304  0.880603
# 331  0.958849  0.557048  0.575742  0.183396  0.176400
# 332  0.391368  0.741138  0.797065  0.734708  0.002875
# 333  0.406627  0.004630  0.201650  0.904151  0.516512
#
# [334 rows x 5 columns]

# %%
newdf2 = newdf.copy()

# %%
newdf
# Out:
#             0         1         2         3         4
# 0        9793  0.402848  0.696546  0.732249  0.432445
# 1    0.861833  0.513092  0.504721  0.278287  0.400661
# 2    0.858289  0.862285  0.814329  0.367286  0.341054
# 3    0.906266  0.393929  0.089836  0.340316  0.976024
# 4     0.85777  0.600327  0.456067  0.400450  0.431530
# ..        ...       ...       ...       ...       ...
# 329   0.47562  0.617081  0.594165  0.892920  0.961394
# 330  0.531252  0.904089  0.724146  0.755304  0.880603
# 331  0.958849  0.557048  0.575742  0.183396  0.176400
# 332  0.391368  0.741138  0.797065  0.734708  0.002875
# 333  0.406627  0.004630  0.201650  0.904151  0.516512
#
# [334 rows x 5 columns]

# %%
newdf2
# Out:
#             0         1         2         3         4
# 0       98776  0.402848  0.696546  0.732249  0.432445
# 1    0.861833  0.513092  0.504721  0.278287  0.400661
# 2    0.858289  0.862285  0.814329  0.367286  0.341054
# 3    0.906266  0.393929  0.089836  0.340316  0.976024
# 4     0.85777  0.600327  0.456067  0.400450  0.431530
# ..        ...       ...       ...       ...       ...
# 329   0.47562  0.617081  0.594165  0.892920  0.961394
# 330  0.531252  0.904089  0.724146  0.755304  0.880603
# 331  0.958849  0.557048  0.575742  0.183396  0.176400
# 332  0.391368  0.741138  0.797065  0.734708  0.002875
# 333  0.406627  0.004630  0.201650  0.904151  0.516512
#
# [334 rows x 5 columns]

# %%
newdf2
# Out:
#             0         1         2         3         4
# 0       98776  0.402848  0.696546  0.732249  0.432445
# 1    0.861833  0.513092  0.504721  0.278287  0.400661
# 2    0.858289  0.862285  0.814329  0.367286  0.341054
# 3    0.906266  0.393929  0.089836  0.340316  0.976024
# 4     0.85777  0.600327  0.456067  0.400450  0.431530
# ..        ...       ...       ...       ...       ...
# 329   0.47562  0.617081  0.594165  0.892920  0.961394
# 330  0.531252  0.904089  0.724146  0.755304  0.880603
# 331  0.958849  0.557048  0.575742  0.183396  0.176400
# 332  0.391368  0.741138  0.797065  0.734708  0.002875
# 333  0.406627  0.004630  0.201650  0.904151  0.516512
#
# [334 rows x 5 columns]

# %%
newdf2.loc[0,0] = 654

# %%
newdf2
# Out:
#             0         1         2         3         4
# 0         654  0.402848  0.696546  0.732249  0.432445
# 1    0.861833  0.513092  0.504721  0.278287  0.400661
# 2    0.858289  0.862285  0.814329  0.367286  0.341054
# 3    0.906266  0.393929  0.089836  0.340316  0.976024
# 4     0.85777  0.600327  0.456067  0.400450  0.431530
# ..        ...       ...       ...       ...       ...
# 329   0.47562  0.617081  0.594165  0.892920  0.961394
# 330  0.531252  0.904089  0.724146  0.755304  0.880603
# 331  0.958849  0.557048  0.575742  0.183396  0.176400
# 332  0.391368  0.741138  0.797065  0.734708  0.002875
# 333  0.406627  0.004630  0.201650  0.904151  0.516512
#
# [334 rows x 5 columns]

# %%
newdf2.columns = list("ABCDE")

# %%
newdf2
# Out:
#             A         B         C         D         E
# 0         654  0.402848  0.696546  0.732249  0.432445
# 1    0.861833  0.513092  0.504721  0.278287  0.400661
# 2    0.858289  0.862285  0.814329  0.367286  0.341054
# 3    0.906266  0.393929  0.089836  0.340316  0.976024
# 4     0.85777  0.600327  0.456067  0.400450  0.431530
# ..        ...       ...       ...       ...       ...
# 329   0.47562  0.617081  0.594165  0.892920  0.961394
# 330  0.531252  0.904089  0.724146  0.755304  0.880603
# 331  0.958849  0.557048  0.575742  0.183396  0.176400
# 332  0.391368  0.741138  0.797065  0.734708  0.002875
# 333  0.406627  0.004630  0.201650  0.904151  0.516512
#
# [334 rows x 5 columns]

# %%
newdf2.loc[0,0] = 4046

# %%
newdf2
# Out:
#             A         B         C         D         E       0
# 0         654  0.402848  0.696546  0.732249  0.432445  4046.0
# 1    0.861833  0.513092  0.504721  0.278287  0.400661     NaN
# 2    0.858289  0.862285  0.814329  0.367286  0.341054     NaN
# 3    0.906266  0.393929  0.089836  0.340316  0.976024     NaN
# 4     0.85777  0.600327  0.456067  0.400450  0.431530     NaN
# ..        ...       ...       ...       ...       ...     ...
# 329   0.47562  0.617081  0.594165  0.892920  0.961394     NaN
# 330  0.531252  0.904089  0.724146  0.755304  0.880603     NaN
# 331  0.958849  0.557048  0.575742  0.183396  0.176400     NaN
# 332  0.391368  0.741138  0.797065  0.734708  0.002875     NaN
# 333  0.406627  0.004630  0.201650  0.904151  0.516512     NaN
#
# [334 rows x 6 columns]

# %%
newdf2.drop(0,axis = 1)
# Out:
#             A         B         C         D         E
# 0         654  0.402848  0.696546  0.732249  0.432445
# 1    0.861833  0.513092  0.504721  0.278287  0.400661
# 2    0.858289  0.862285  0.814329  0.367286  0.341054
# 3    0.906266  0.393929  0.089836  0.340316  0.976024
# 4     0.85777  0.600327  0.456067  0.400450  0.431530
# ..        ...       ...       ...       ...       ...
# 329   0.47562  0.617081  0.594165  0.892920  0.961394
# 330  0.531252  0.904089  0.724146  0.755304  0.880603
# 331  0.958849  0.557048  0.575742  0.183396  0.176400
# 332  0.391368  0.741138  0.797065  0.734708  0.002875
# 333  0.406627  0.004630  0.201650  0.904151  0.516512
#
# [334 rows x 5 columns]

# %%
newdf2.loc[[1,2],['C','D']]
# Out:
#           C         D
# 1  0.504721  0.278287
# 2  0.814329  0.367286

# %%
newdf2.loc[:,['C','D']]
# Out:
#             C         D
# 0    0.696546  0.732249
# 1    0.504721  0.278287
# 2    0.814329  0.367286
# 3    0.089836  0.340316
# 4    0.456067  0.400450
# ..        ...       ...
# 329  0.594165  0.892920
# 330  0.724146  0.755304
# 331  0.575742  0.183396
# 332  0.797065  0.734708
# 333  0.201650  0.904151
#
# [334 rows x 2 columns]

# %%
newdf2.loc[[1,2],:]
# Out:
#           A         B         C         D         E   0
# 1  0.861833  0.513092  0.504721  0.278287  0.400661 NaN
# 2  0.858289  0.862285  0.814329  0.367286  0.341054 NaN

# %%
newdf2.drop(0, axis=1, inplace=True)

# %%
newdf2.loc[(newdf2['A']>0.3)]
# Out:
#             A         B         C         D         E
# 0         654  0.402848  0.696546  0.732249  0.432445
# 1    0.861833  0.513092  0.504721  0.278287  0.400661
# 2    0.858289  0.862285  0.814329  0.367286  0.341054
# 3    0.906266  0.393929  0.089836  0.340316  0.976024
# 4     0.85777  0.600327  0.456067  0.400450  0.431530
# ..        ...       ...       ...       ...       ...
# 329   0.47562  0.617081  0.594165  0.892920  0.961394
# 330  0.531252  0.904089  0.724146  0.755304  0.880603
# 331  0.958849  0.557048  0.575742  0.183396  0.176400
# 332  0.391368  0.741138  0.797065  0.734708  0.002875
# 333  0.406627  0.004630  0.201650  0.904151  0.516512
#
# [227 rows x 5 columns]

# %%
newdf2.loc[(newdf2['A']>0.3) & (newdf2['C']>0.1)]
# Out:
#             A         B         C         D         E
# 0         654  0.402848  0.696546  0.732249  0.432445
# 1    0.861833  0.513092  0.504721  0.278287  0.400661
# 2    0.858289  0.862285  0.814329  0.367286  0.341054
# 4     0.85777  0.600327  0.456067  0.400450  0.431530
# 6    0.744648  0.076086  0.612327  0.452067  0.649299
# ..        ...       ...       ...       ...       ...
# 329   0.47562  0.617081  0.594165  0.892920  0.961394
# 330  0.531252  0.904089  0.724146  0.755304  0.880603
# 331  0.958849  0.557048  0.575742  0.183396  0.176400
# 332  0.391368  0.741138  0.797065  0.734708  0.002875
# 333  0.406627  0.004630  0.201650  0.904151  0.516512
#
# [205 rows x 5 columns]

# %%
newdf2.iloc[0,4]
# Out:
# np.float64(0.43244519456079733)

# %%
newdf2.iloc[[0,1],[1,2]]
# Out:
#           B         C
# 0  0.402848  0.696546
# 1  0.513092  0.504721

# %%
newdf2.drop([0])
# Out:
#             A         B         C         D         E
# 1    0.861833  0.513092  0.504721  0.278287  0.400661
# 2    0.858289  0.862285  0.814329  0.367286  0.341054
# 3    0.906266  0.393929  0.089836  0.340316  0.976024
# 4     0.85777  0.600327  0.456067  0.400450  0.431530
# 5     0.27208  0.910888  0.765367  0.900135  0.560617
# ..        ...       ...       ...       ...       ...
# 329   0.47562  0.617081  0.594165  0.892920  0.961394
# 330  0.531252  0.904089  0.724146  0.755304  0.880603
# 331  0.958849  0.557048  0.575742  0.183396  0.176400
# 332  0.391368  0.741138  0.797065  0.734708  0.002875
# 333  0.406627  0.004630  0.201650  0.904151  0.516512
#
# [333 rows x 5 columns]

# %%
newdf2.drop(['A','C'],axis = 1)
# Out:
#             B         D         E
# 0    0.402848  0.732249  0.432445
# 1    0.513092  0.278287  0.400661
# 2    0.862285  0.367286  0.341054
# 3    0.393929  0.340316  0.976024
# 4    0.600327  0.400450  0.431530
# ..        ...       ...       ...
# 329  0.617081  0.892920  0.961394
# 330  0.904089  0.755304  0.880603
# 331  0.557048  0.183396  0.176400
# 332  0.741138  0.734708  0.002875
# 333  0.004630  0.904151  0.516512
#
# [334 rows x 3 columns]

# %%
newdf2.reset_index(drop=True,inplace= True)

# %%
newdf2.head(2)
# Out:
#           A         B         C         D         E
# 0       654  0.402848  0.696546  0.732249  0.432445
# 1  0.861833  0.513092  0.504721  0.278287  0.400661

# %%
newdf2['B'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 329    False
# 330    False
# 331    False
# 332    False
# 333    False
# Name: B, Length: 334, dtype: bool

# %%
newdf2.loc[:,['B']]=  56

# %%
newdf2
# Out:
#             A   B         C         D         E
# 0         654  56  0.696546  0.732249  0.432445
# 1    0.861833  56  0.504721  0.278287  0.400661
# 2    0.858289  56  0.814329  0.367286  0.341054
# 3    0.906266  56  0.089836  0.340316  0.976024
# 4     0.85777  56  0.456067  0.400450  0.431530
# ..        ...  ..       ...       ...       ...
# 329   0.47562  56  0.594165  0.892920  0.961394
# 330  0.531252  56  0.724146  0.755304  0.880603
# 331  0.958849  56  0.575742  0.183396  0.176400
# 332  0.391368  56  0.797065  0.734708  0.002875
# 333  0.406627  56  0.201650  0.904151  0.516512
#
# [334 rows x 5 columns]

# %%
newdf2.shape
# Out:
# (334, 5)

# %%
newdf2.info
# Out:
# <bound method DataFrame.info of             A   B         C         D         E
# 0         654  56  0.696546  0.732249  0.432445
# 1    0.861833  56  0.504721  0.278287  0.400661
# 2    0.858289  56  0.814329  0.367286  0.341054
# 3    0.906266  56  0.089836  0.340316  0.976024
# 4     0.85777  56  0.456067  0.400450  0.431530
# ..        ...  ..       ...       ...       ...
# 329   0.47562  56  0.594165  0.892920  0.961394
# 330  0.531252  56  0.724146  0.755304  0.880603
# 331  0.958849  56  0.575742  0.183396  0.176400
# 332  0.391368  56  0.797065  0.734708  0.002875
# 333  0.406627  56  0.201650  0.904151  0.516512
#
# [334 rows x 5 columns]>
